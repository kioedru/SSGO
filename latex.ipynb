# %%
# # db分数表格
# % \begin{table}
# %     \caption{Davies Bouldin Score comparison of different protein feature represents}
# %     \label{tab 3}
# %     \centering
# %     \setlength{\tabcolsep}{8mm}{
# %     \begin{threeparttable}
# %     \begin{tabular}{llll}
# %     \toprule
# %     \textbf{Representation} &\multicolumn{1}{c}{\bf BPO}  &\multicolumn{1}{c}{\bf MFO} &\multicolumn{1}{c}{\bf CCO}\\
# %     \midrule
# %     o\_PPI       & 1.855 & 2.250 & 2.243  \\
# %     o\_attribute & 2.128 & 2.387 & 2.128  \\
# %     o\_sequence  & 2.061 & 2.344 & 2.356  \\
# %     SFE\_embedding   & 1.626 & 2.207 & 1.908  \\
# %     IFE\_embedding   & 1.896 & 2.130 & 1.360  \\
# %     DSM\_embedding   & \textbf{1.619} & \textbf{2.079} & \textbf{0.962}  \\
# %     \bottomrule
# %     \end{tabular}
    
# %     \begin{tablenotes}
# %             \footnotesize
            
# %             \item o\_PPI:  the orignal PPI network embedding.
# %             \item o\_attribute: the orignal protein attribute embedding.
# %             \item o\_sequence: the orignal protein language model embedding.
# %             \item SFE\_embedding: the embedding from the Shared Feature Extraction branch.
# %             \item IFE\_embedding: the embedding from the Interaction Feature Extraction branch.
# %             \item DSM\_embedding: the embedding from the Dynamic Selection Mechanism.
           
# %     \end{tablenotes}
# %     \end{threeparttable}
    
# %     }
    
# % \end{table}

# %%
# # 消融实验表格
# % \begin{table*}[t]
# % \caption{Performance comparison of different Component methods.\label{tab 4}}
# % \tabcolsep=0pt
# % \tiny
# % \begin{threeparttable}
    
# % \begin{tabular*}{\textwidth}{@{\extracolsep{\fill}}llllllllllllllll@{\extracolsep{\fill}}}
# % \toprule
# % \multirow{2}{*}{\textbf{Method}} & \multicolumn{3}{@{}c@{}}{\textbf{F$_{\max}$}} & \multicolumn{3}{@{}c@{}}{\textbf{m-AUPR}} & \multicolumn{3}{@{}c@{}}{\textbf{M-AUPR}} & \multicolumn{3}{@{}c@{}}{\textbf{F1}} & \multicolumn{3}{@{}c@{}}{\textbf{ACC}} \\

# % \cline{2-4}\cline{5-7}\cline{8-10}\cline{11-13}\cline{14-16} \vspace{0.1ex}\\
# % & \textbf{BPO} & \textbf{MFO} & \textbf{CCO} & \textbf{BPO} & \textbf{MFO} & \textbf{CCO} & \textbf{BPO} & \textbf{MFO} & \textbf{CCO} & \textbf{BPO} & \textbf{MFO} & \textbf{CCO} & \textbf{BPO} & \textbf{MFO} & \textbf{CCO} \\
# % \midrule

# % BDGO-$w/o$ BInM              & 0.431          & 0.204          & 0.390          & 0.323          & 0.133          & 0.315          & 0.170          & 0.082          & 0.218          & 0.256          & 0.198          & 0.337          & 0.330          & 0.090          & 0.176           \\
# % BDGO-$w/o$ DSM                & 0.404          & 0.167          & 0.373          & 0.266          & 0.131          & 0.321          & 0.170          & 0.083          & 0.251          & 0.264          & 0.176          & 0.321          & 0.313          & 0.085          & 0.202           \\
# % MSL-branch               & 0.428          & 0.231          & 0.388          & 0.323          & 0.153          & 0.322          & 0.154          & 0.082          & 0.188          & 0.264          & 0.240          & 0.292          & 0.324          & 0.075          & 0.168           \\
# % MIL-branch               & 0.396          & 0.256          & 0.377          & 0.270          & 0.112          & 0.333          & 0.156          & 0.083          & 0.229          & 0.240          & 0.142          & 0.305          & 0.313          & 0.063          & 0.210           \\
# % $\textbf{BDGO(ours)}$           & \textbf{0.440} & \textbf{0.282} & \textbf{0.421} & \textbf{0.332} & \textbf{0.172} & \textbf{0.392} & \textbf{0.171} & \textbf{0.088} & \textbf{0.257} & \textbf{0.264} & \textbf{0.263} & \textbf{0.337} & \textbf{0.331} & \textbf{0.103} & \textbf{0.210}  \\

# % \bottomrule
# % \end{tabular*}
# % \begin{tablenotes}
# % \tiny

# % \item BDGO-$w/o$ BInM : BDGO removes the Bidirectional Interaction Module (BInM).
# % \item BDGO-$w/o$ DSM : BDGO removes the Dynamic Selection Mechanism (DSM).
# % \item MSL-branch: BDGO's multimodal shared learning branch.
# % \item MIL-branch : BDGO's multimodal interactive learning branch.
# % \item $BDGO (ours)$ : Our complete model.

# % \end{tablenotes}
# % \end{threeparttable}

# % \end{table*}

# %%
# 图
# % \begin{figure}
# %     \centering
# %     \includegraphics[width=0.5\linewidth]{t-SNE_P.png}\\
# %     \tiny BPO \vspace{3ex}\\
# %     \includegraphics[width=0.5\linewidth]{t-SNE_F.png}\\
# %     \tiny MFO \vspace{3ex}\\
# %     \includegraphics[width=0.5\linewidth]{t-SNE_C.png}\\
# %     \tiny CCO \vspace{3ex}\\
# %     \caption{Visualization of different feature representations for DBGO in BPO, MFO and CCO.}
# %     \label{Figure 1}
# % \end{figure}

# %%
# % \begin{table*}[t]
# % \caption{Performance comparison of different computational methods.\label{tab 2}}
# % \tabcolsep=0pt
# % \tiny
# % \begin{tabular*}{\textwidth}{@{\extracolsep{\fill}}llllllllllllllll@{\extracolsep{\fill}}}
# % \toprule
# % \multirow{2}{*}{\textbf{Method}} & \multicolumn{3}{@{}c@{}}{\textbf{F$_{\max}$}} & \multicolumn{3}{@{}c@{}}{\textbf{m-AUPR}} & \multicolumn{3}{@{}c@{}}{\textbf{M-AUPR}} & \multicolumn{3}{@{}c@{}}{\textbf{F1}} & \multicolumn{3}{@{}c@{}}{\textbf{ACC}} \\

# % \cline{2-4}\cline{5-7}\cline{8-10}\cline{11-13}\cline{14-16} \vspace{0.1ex}\\
# % & \textbf{BPO} & \textbf{MFO} & \textbf{CCO} & \textbf{BPO} & \textbf{MFO} & \textbf{CCO} & \textbf{BPO} & \textbf{MFO} & \textbf{CCO} & \textbf{BPO} & \textbf{MFO} & \textbf{CCO} & \textbf{BPO} & \textbf{MFO} & \textbf{CCO} \\


# % \midrule

# % Naïve\citep{radivojac2013large}       & 0.051          & 0.177          & 0.121          & 0.024          & 0.050          & 0.047          & 0.048          & 0.029          & 0.060          & 0.035          & 0.004          & 0.070          & 0.000          & 0.000          & 0.000           \\
# % BLAST\citep{altschul1990basic}       & 0.270          & 0.122          & 0.196          & 0.110          & 0.044          & 0.084          & 0.093          & 0.084          & 0.082          & 0.159          & 0.064          & 0.107          & 0.071          & 0.015          & 0.034           \\
# % GeneMANIA\citep{mostafavi2008genemania}   & 0.000          & 0.000          & 0.031          & 0.042          & 0.050          & 0.103          & 0.160          & 0.109          & 0.150          & 0.054          & 0.008          & 0.123          & 0.000          & 0.000          & 0.000           \\
# % Mashup\citep{cho2016compact}      & 0.075          & 0.058          & 0.000          & 0.238          & 0.053          & 0.179          & 0.146          & 0.089          & 0.104          & 0.248          & 0.106          & 0.202          & 0.044          & 0.038          & 0.000           \\
# % deepNF\citep{gligorijevic2018deepnf}      & 0.394          & 0.153          & 0.297          & 0.303          & 0.089          & 0.178          & \underline{0.174}  & \underline{0.118}  & 0.155          & 0.228          & 0.117          & 0.205          & 0.158          & 0.034          & 0.080           \\
# % NetQuilt\citep{barot2021netquilt}    & 0.164          & 0.081          & 0.138          & 0.077          & 0.045          & 0.081          & 0.081          & 0.064          & 0.063          & 0.114          & 0.070          & 0.108          & 0.048          & 0.017          & 0.037           \\
# % Graph2GO\citep{fan2020graph2go}    & 0.335          & 0.196          & 0.298          & 0.237          & 0.103          & 0.215          & 0.150          & 0.111          & 0.159          & 0.222          & 0.167          & 0.261          & 0.257          & 0.114          & \underline{0.180}           \\
# % DeepGraphGO\citep{you2021deepgraphgo} & 0.327          & 0.142          & 0.209          & 0.210          & 0.080          & 0.133          & 0.133          & 0.098          & 0.133          & 0.238          & 0.165          & 0.210          & 0.153          & 0.048          & 0.066           \\
# % CFAGO\citep{wu2023cfago}       & \underline{0.439}          & \underline{0.236}          & \underline{0.366}         & \underline{0.328}          & \underline{0.159}          & \underline{0.337}          & \textbf{0.188} & \textbf{0.138} & \underline{0.210}  & \textbf{0.283} & \underline{0.234}  & \underline{0.314}  & \textbf{0.338} & \underline{0.100}  & \textbf{0.210}  \\
# % BDGO(ours)  & \textbf{0.440} & \textbf{0.282} & \textbf{0.421} & \textbf{0.332} & \textbf{0.172} & \textbf{0.392} & 0.171          & 0.088          & \textbf{0.257} & \underline{0.264}  & \textbf{0.263} & \textbf{0.337} & \underline{0.331}  & \textbf{0.103} & \textbf{0.210}  \\

# % \bottomrule
# % \end{tabular*}

# % \end{table*}
