# %%
import torch
import sys

sys.path.append("/home/Kioedru/code/SSGO")
model = torch.load(
    "/home/Kioedru/code/SSGO/codespace/pretrain/bimamba/9606/bimamba.pkl"
)
print(model.state_dict().keys())
# Out:
# odict_keys(['transformerEncoder.encoder.layers.0.self_attn.A_log', 'transformerEncoder.encoder.layers.0.self_attn.A_b_log', 'transformerEncoder.encoder.layers.0.self_attn.D', 'transformerEncoder.encoder.layers.0.self_attn.D_b', 'transformerEncoder.encoder.layers.0.self_attn.in_proj.weight', 'transformerEncoder.encoder.layers.0.self_attn.conv1d.weight', 'transformerEncoder.encoder.layers.0.self_attn.conv1d.bias', 'transformerEncoder.encoder.layers.0.self_attn.conv1d_b.weight', 'transformerEncoder.encoder.layers.0.self_attn.conv1d_b.bias', 'transformerEncoder.encoder.layers.0.self_attn.x_proj.weight', 'transformerEncoder.encoder.layers.0.self_attn.x_proj_b.weight', 'transformerEncoder.encoder.layers.0.self_attn.dt_proj.weight', 'transformerEncoder.encoder.layers.0.self_attn.dt_proj.bias', 'transformerEncoder.encoder.layers.0.self_attn.dt_proj_b.weight', 'transformerEncoder.encoder.layers.0.self_attn.dt_proj_b.bias', 'transformerEncoder.encoder.layers.0.self_attn.out_proj.weight', 'transformerEncoder.encoder.layers.0.linear1.weight', 'transformerEncoder.encoder.layers.0.linear1.bias', 'transformerEncoder.encoder.layers.0.linear2.weight', 'transformerEncoder.encoder.layers.0.linear2.bias', 'transformerEncoder.encoder.layers.0.norm1.weight', 'transformerEncoder.encoder.layers.0.norm1.bias', 'transformerEncoder.encoder.layers.0.norm2.weight', 'transformerEncoder.encoder.layers.0.norm2.bias', 'transformerEncoder.encoder.layers.1.self_attn.A_log', 'transformerEncoder.encoder.layers.1.self_attn.A_b_log', 'transformerEncoder.encoder.layers.1.self_attn.D', 'transformerEncoder.encoder.layers.1.self_attn.D_b', 'transformerEncoder.encoder.layers.1.self_attn.in_proj.weight', 'transformerEncoder.encoder.layers.1.self_attn.conv1d.weight', 'transformerEncoder.encoder.layers.1.self_attn.conv1d.bias', 'transformerEncoder.encoder.layers.1.self_attn.conv1d_b.weight', 'transformerEncoder.encoder.layers.1.self_attn.conv1d_b.bias', 'transformerEncoder.encoder.layers.1.self_attn.x_proj.weight', 'transformerEncoder.encoder.layers.1.self_attn.x_proj_b.weight', 'transformerEncoder.encoder.layers.1.self_attn.dt_proj.weight', 'transformerEncoder.encoder.layers.1.self_attn.dt_proj.bias', 'transformerEncoder.encoder.layers.1.self_attn.dt_proj_b.weight', 'transformerEncoder.encoder.layers.1.self_attn.dt_proj_b.bias', 'transformerEncoder.encoder.layers.1.self_attn.out_proj.weight', 'transformerEncoder.encoder.layers.1.linear1.weight', 'transformerEncoder.encoder.layers.1.linear1.bias', 'transformerEncoder.encoder.layers.1.linear2.weight', 'transformerEncoder.encoder.layers.1.linear2.bias', 'transformerEncoder.encoder.layers.1.norm1.weight', 'transformerEncoder.encoder.layers.1.norm1.bias', 'transformerEncoder.encoder.layers.1.norm2.weight', 'transformerEncoder.encoder.layers.1.norm2.bias', 'transformerEncoder.encoder.layers.2.self_attn.A_log', 'transformerEncoder.encoder.layers.2.self_attn.A_b_log', 'transformerEncoder.encoder.layers.2.self_attn.D', 'transformerEncoder.encoder.layers.2.self_attn.D_b', 'transformerEncoder.encoder.layers.2.self_attn.in_proj.weight', 'transformerEncoder.encoder.layers.2.self_attn.conv1d.weight', 'transformerEncoder.encoder.layers.2.self_attn.conv1d.bias', 'transformerEncoder.encoder.layers.2.self_attn.conv1d_b.weight', 'transformerEncoder.encoder.layers.2.self_attn.conv1d_b.bias', 'transformerEncoder.encoder.layers.2.self_attn.x_proj.weight', 'transformerEncoder.encoder.layers.2.self_attn.x_proj_b.weight', 'transformerEncoder.encoder.layers.2.self_attn.dt_proj.weight', 'transformerEncoder.encoder.layers.2.self_attn.dt_proj.bias', 'transformerEncoder.encoder.layers.2.self_attn.dt_proj_b.weight', 'transformerEncoder.encoder.layers.2.self_attn.dt_proj_b.bias', 'transformerEncoder.encoder.layers.2.self_attn.out_proj.weight', 'transformerEncoder.encoder.layers.2.linear1.weight', 'transformerEncoder.encoder.layers.2.linear1.bias', 'transformerEncoder.encoder.layers.2.linear2.weight', 'transformerEncoder.encoder.layers.2.linear2.bias', ' ...

# %%
torch.save(
    model.state_dict(),
    "/home/Kioedru/code/SSGO/codespace/pretrain/bimamba/9606/bimamba.pth",
)
